# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Automobile_Data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df["price"].replace('?', np.nan, inplace=True)

# %%
df['price'] = pd.to_numeric(df['price'])

# %%
df['price'] = df['price'].fillna(df['price'].mean())

# %%
df['num-of-doors'].replace('?', np.nan, inplace=True)

# %%
df['num-of-doors']= df['num-of-doors'].fillna(df['num-of-doors'].mode())

# %%
df["normalized-losses"].replace('?', np.nan, inplace=True)

# %%
df['normalized-losses'].fillna(df['normalized-losses'].median())
# Out:
# 0      115.0
# 1      115.0
# 2      115.0
# 3        164
# 4        164
#        ...
# 200       95
# 201       95
# 202       95
# 203       95
# 204       95
# Name: normalized-losses, Length: 205, dtype: object

# %%
df["horsepower"].replace('?', np.nan, inplace=True)

# %%
df['horsepower'].fillna(df['horsepower'].median())
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
df['horsepower']= pd.to_numeric(df['horsepower'])

# %%
sns.distplot(df['normalized-losses'])
plt.show()

# %%
df.hist(figsize=(20,20));

# %%
sns.distplot(df['normalized-losses'], kde=False, rug=True)
plt.show()

# %%
sns.jointplot(x='engine-size', y='horsepower', data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.make.value_counts().nlargest(10).plot(kind='bar', figsize=(16,7))
plt.show()

# %%
df['bore'] = pd.to_numeric(df['bore'], errors='coerce')
df['bore'] = df['bore'].fillna(df['bore'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df['horsepower'].isna().any()
# Out:
# True

# %%
df['horsepower'].fillna(0)
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
df['horsepower']= pd.to_numeric(df['horsepower'])

# %%
df['horsepower'].dtype
# Out:
# dtype('float64')

# %%
df['normalized-losses']= pd.to_numeric(df['normalized-losses'])

# %%
sns.jointplot(x='engine-size', y='horsepower', data=df, kind='hex')
plt.show()

# %%
sns.jointplot(x='engine-size', y='horsepower', data=df, kind='resid')
plt.show()

# %%
sns.jointplot(x='engine-size', y='horsepower', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='engine-size', y='horsepower', data=df, kind='kde')

# %%
sns.pairplot(df[['city-mpg','engine-size', 'horsepower']])

# %%
sns.stripplot(x='fuel-type', y= 'horsepower', data=df)
# Out:
# <AxesSubplot:xlabel='fuel-type', ylabel='horsepower'>

# %%
sns.swarmplot(x='fuel-type', y= 'horsepower', data=df , size=4)
# Out:
# <AxesSubplot:xlabel='fuel-type', ylabel='horsepower'>

# %%
sns.boxplot(x= 'num-of-doors', y='horsepower', data=df)
# Out:
# <AxesSubplot:xlabel='num-of-doors', ylabel='horsepower'>

# %%
sns.barplot(x='body-style', y='horsepower', data=df, hue='engine-location')
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='horsepower'>

# %%
sns.countplot(x='body-style', data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
sns.countplot(x='fuel-type', data=df)
plt.show()

# %%
sns.pointplot(x= 'fuel-system', y='horsepower', data=df, hue='num-of-doors')
# Out:
# <AxesSubplot:xlabel='fuel-system', ylabel='horsepower'>

# %%
sns.catplot(x= 'fuel-type', y='horsepower', data=df, hue='num-of-doors', col='engine-location', kind='swarm', height=7)

# %%
sns.catplot(x= 'fuel-type', y='horsepower', data=df, hue='num-of-doors', col='engine-location', kind='bar', height=7, ci= None)

# %%
sns.lmplot(x='horsepower', y='price', data=df, hue='fuel-type')

# %%
sns.jointplot(y= 'price' , x= 'horsepower', data=df, kind='reg' )

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()
